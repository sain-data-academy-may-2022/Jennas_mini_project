# %%
# %reload_ext sql

# %%
# %sql mysql+pymysql://root:password@localhost:3306/new_db

# %%
# %sql SELECT * FROM food
# Out:
#  * mysql+pymysql://root:***@localhost:3306/new_db
# 6 rows affected.
# [(1, 'Chocolate McChocolate Cake', 'Cake that is chocolate, what more do you need to know', Decimal('20'), 73),
#  (2, 'Salad', 'A boring choice for a boring person', Decimal('666'), 90),
#  (3, 'Hot Chocolate', 'With Coconut milk to bring that warm chocolately cozyness', Decimal('10'), 89),
#  (4, 'CostaLot Special', 'Two slices of toast with jam but we will charge the cost of a whole loaf', Decimal('12'), 89),
#  (5, 'Vegan Pepperoni Pizza', 'With lots of meat and chesee from animals just what you Vegans want right', Decimal('23'), 68),
#  (8, 'Pie', 'Steak & Ale', Decimal('1000'), 70)]

# %%
import numpy as np
import matplotlib.pyplot as plt 

food_name = %sql SELECT food_name FROM food
quantity = %sql SELECT quantity FROM food
quantity1 = int(quantity[0][0])
quantity2 = int(quantity[1][0])
quantity3 = int(quantity[2][0])
quantity4 = int(quantity[3][0])
quantity5 = int(quantity[4][0])
quantity6 = int(quantity[5][0])
quantity_list = [quantity1, quantity2, quantity3, quantity4, quantity5, quantity6 ]
print(quantity_list)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/new_db
# 6 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/new_db
# 6 rows affected.
# [73, 90, 89, 89, 68, 70]

# %%
plt.figure(figsize=(18, 7))
x_data = food_name
y_data = quantity_list


x_pos = np.arange(len(x_data))
plt.bar(x_pos, y_data)
plt.xticks(x_pos, x_data)
plt.ylabel('Stock')
plt.title('Stock Chart')
plt.show()

# %%
from database_func import total_sales


plt.figure(figsize=(18, 7))
x_data = food_name
y_data = total_sales


x_pos = np.arange(len(x_data))
plt.bar(x_pos, y_data)
plt.xticks(x_pos, x_data)
plt.ylabel('Items sold')
plt.title('Total Sales')
plt.show()
